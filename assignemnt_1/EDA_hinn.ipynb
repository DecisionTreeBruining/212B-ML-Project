# %%
#Library imports
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import dataset from kaggle
mental_health = pd.read_csv('mental_health.csv')

# check the shape
mental_health.shape
# Out:
# (292364, 17)

# %%
mental_health.head(5)
# Out:
#          Timestamp  Gender        Country Occupation self_employed  \
# 0  8/27/2014 11:29  Female  United States  Corporate           NaN
# 1  8/27/2014 11:31  Female  United States  Corporate           NaN
# 2  8/27/2014 11:32  Female  United States  Corporate           NaN
# 3  8/27/2014 11:37  Female  United States  Corporate            No
# 4  8/27/2014 11:43  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
# 2            Yes       Yes    1-14 days            Yes             No
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# ...

# %%
mental_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292364 entries, 0 to 292363
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Timestamp                292364 non-null  object
#  1   Gender                   292364 non-null  object
#  2   Country                  292364 non-null  object
#  3   Occupation               292364 non-null  object
#  4   self_employed            287162 non-null  object
#  5   family_history           292364 non-null  object
#  6   treatment                292364 non-null  object
#  7   Days_Indoors             292364 non-null  object
#  8   Growing_Stress           292364 non-null  object
#  9   Changes_Habits           292364 non-null  object
#  10  Mental_Health_History    292364 non-null  object
#  11  Mood_Swings              292364 non-null  object
#  12  Coping_Struggles         292364 non-null  object
# ...

# %%
mental_health.columns
# Out:
# Index(['Timestamp', 'Gender', 'Country', 'Occupation', 'self_employed',
#        'family_history', 'treatment', 'Days_Indoors', 'Growing_Stress',
#        'Changes_Habits', 'Mental_Health_History', 'Mood_Swings',
#        'Coping_Struggles', 'Work_Interest', 'Social_Weakness',
#        'mental_health_interview', 'care_options'],
#       dtype='object')

# %%
# check for missing values
mental_health.isnull().sum()
# Out:
# Timestamp                     0
# Gender                        0
# Country                       0
# Occupation                    0
# self_employed              5202
# family_history                0
# treatment                     0
# Days_Indoors                  0
# Growing_Stress                0
# Changes_Habits                0
# Mental_Health_History         0
# Mood_Swings                   0
# Coping_Struggles              0
# Work_Interest                 0
# Social_Weakness               0
# mental_health_interview       0
# care_options                  0
# dtype: int64

# %%
# count plot for all feature vairiables in the dataset
count_vis = mental_health.drop(["Timestamp"], axis = 1) # get rid of Timstamp 

fig, ((ax1, ax2), (ax3, ax4),(ax5,ax6),(ax7,ax8),(ax9,ax10)) = plt.subplots(ncols = 2,nrows = 5)
plt_1 = sns.countplot(y = count_vis['Occupation'], ax = ax1)
plt_2 = sns.countplot(y = count_vis['family_history'], ax = ax2)
plt_3 = sns.countplot(y = count_vis['treatment'], ax = ax3)
plt_4 = sns.countplot(y = count_vis['Days_Indoors'], ax = ax4)
plt_5 = sns.countplot(y = count_vis['Mental_Health_History'], ax = ax5)
plt_6 = sns.countplot(y = count_vis['Work_Interest'], ax = ax6)

# adjusting the figure size for better visual experience
fig = plt.gcf()
fig.set_size_inches(15,20)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(ncols = 2,nrows = 2)
plt_1 = sns.countplot(y = count_vis['Growing_Stress'], ax = ax1)
plt_2 = sns.countplot(y = count_vis['Mood_Swings'], ax = ax2)
plt_3 = sns.countplot(y = count_vis['Coping_Struggles'], ax = ax3)

# adjusting the figure size for better visual experience
fig = plt.gcf()
fig.set_size_inches(10,10)

# %%
#pip install ucimlrepo
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
national_health_and_nutrition_health_survey_2013_2014_nhanes_age_prediction_subset = fetch_ucirepo(id=887) 
  
# data (as pandas dataframes) 
X = national_health_and_nutrition_health_survey_2013_2014_nhanes_age_prediction_subset.data.features 
y = national_health_and_nutrition_health_survey_2013_2014_nhanes_age_prediction_subset.data.targets 
  
# metadata 
print(national_health_and_nutrition_health_survey_2013_2014_nhanes_age_prediction_subset.metadata) 
  
# variable information 
print(national_health_and_nutrition_health_survey_2013_2014_nhanes_age_prediction_subset.variables)
# Out:
# {'uci_id': 887, 'name': 'National Health and Nutrition Health Survey 2013-2014 (NHANES) Age Prediction Subset', 'repository_url': 'https://archive.ics.uci.edu/dataset/887/national+health+and+nutrition+health+survey+2013-2014+(nhanes)+age+prediction+subset', 'data_url': 'https://archive.ics.uci.edu/static/public/887/data.csv', 'abstract': "The National Health and Nutrition Examination Survey (NHANES), administered by the Centers for Disease Control and Prevention (CDC), collects extensive health and nutritional information from a diverse U.S. population. Though expansive, the dataset is often too broad for specific analytical purposes. In this sub-dataset, we narrow our focus to predicting respondents' age by extracting a subset of features from the larger NHANES dataset. These selected features include physiological measurements, lifestyle choices, and biochemical markers, which were hypothesized to have strong correlations with age.", 'area': 'Health and Medicine', 'tasks': ['Classi
# ...

# %%
y.head(3)
# Out:
#   age_group
# 0     Adult
# 1     Adult
# 2     Adult

# %%
X.columns
# Out:
# Index(['RIAGENDR', 'PAQ605', 'BMXBMI', 'LBXGLU', 'DIQ010', 'LBXGLT', 'LBXIN'], dtype='object')

# %%
# correlation heatmap
plt.figure(figsize=(10,10))
sns.heatmap(X.corr(), annot = True, cmap = 'coolwarm', fmt = '.2f')

# %% [markdown]
# ## Heart 2022

# %%
heart_d = pd.read_csv('heart_2022_with_nans.csv')

# %%
heart_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      445132 non-null  object
#  1   Sex                        445132 non-null  object
#  2   GeneralHealth              443934 non-null  object
#  3   PhysicalHealthDays         434205 non-null  float64
#  4   MentalHealthDays           436065 non-null  float64
#  5   LastCheckupTime            436824 non-null  object
#  6   PhysicalActivities         444039 non-null  object
#  7   SleepHours                 439679 non-null  float64
#  8   RemovedTeeth               433772 non-null  object
#  9   HadHeartAttack             442067 non-null  object
#  10  HadAngina                  440727 non-null  object
#  11  HadStroke                  443575 non-null  object
#  12  HadAsthma                  443359 non-null  object
# ...

# %%
# check missing in column 
heart_d.isnull().sum()
# Out:
# State                            0
# Sex                              0
# GeneralHealth                 1198
# PhysicalHealthDays           10927
# MentalHealthDays              9067
# LastCheckupTime               8308
# PhysicalActivities            1093
# SleepHours                    5453
# RemovedTeeth                 11360
# HadHeartAttack                3065
# HadAngina                     4405
# HadStroke                     1557
# HadAsthma                     1773
# HadSkinCancer                 3143
# HadCOPD                       2219
# HadDepressiveDisorder         2812
# HadKidneyDisease              1926
# HadArthritis                  2633
# HadDiabetes                   1087
# DeafOrHardOfHearing          20647
# BlindOrVisionDifficulty      21564
# DifficultyConcentrating      24240
# DifficultyWalking            24012
# DifficultyDressingBathing    23915
# DifficultyErrands            25656
# SmokerStatus                 35462
# ECigaretteUsage              35660
# ...

# %%
# correlation of the numerics
plt.figure(figsize=(10,10))
sns.heatmap(heart_d.corr(), annot = True, cmap = 'coolwarm', fmt = '.2f')

# %%
# check distribution for all variables

fig, ((ax1, ax2), (ax3, ax4),(ax5,ax6),(ax7,ax8),(ax9,ax10)) = plt.subplots(ncols = 2,nrows = 5)
plt_1 = sns.countplot(heart_d['SleepHours'], ax = ax1)
plt_2 = sns.countplot(heart_d['HadHeartAttack'], ax = ax2)
plt_3 = sns.countplot(heart_d['HadStroke'], ax = ax3)
plt_4 = sns.countplot(heart_d['HadAngina'], ax = ax4)
plt_5 = sns.countplot(heart_d['HadStroke'], ax = ax5)
plt_6 = sns.countplot(heart_d['HadAsthma'], ax = ax6)
plt_7 = sns.countplot(heart_d['HadSkinCancer'], ax = ax7)
plt_8 = sns.countplot(heart_d['HadCOPD'], ax = ax8)
plt_9 = sns.countplot(heart_d['HadDepressiveDisorder'], ax = ax9)       
plt_10 = sns.countplot(heart_d['HadKidneyDisease'], ax = ax10)                  
fig = plt.gcf()
fig.set_size_inches(15,20)

# %% [markdown]
# ### todo
# - new variables that group the dummy together (set a threshold)
# - check correlations among dummies
