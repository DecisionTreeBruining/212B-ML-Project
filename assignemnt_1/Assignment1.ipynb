# %% [markdown]
# # DecisionTreeBruining: Assignment 1
#
# Describe the problem and how the Dataset explains the problem by specifying the response and the predicters.

# %% [markdown]
# ## Document Setup

# %%
from google.colab import userdata # Pull Secret info from user.
import rpy2 # To allow R code in the notebook

# Start code block with `%%R` to use R.
# %load_ext rpy2.ipython

# %% [markdown]
# ### Connecting to Github
# create a personal token (Classic) and copy the key to the colab secrets
#
# 1.   In [Github](https://github.com/settings/tokens), create a classic token. Don't Share this to anyone or copy directly to Google Colab.
# 2.   Add the Token to your Google Colab Secrets. The key icon to the left. Only you can see this. Call the secret using `userdata.get()`.
# 3.   Make additional secrets for your github email and username.
#
#
#
#
#
# (The key icon to the left). In addition, make a secret for email and username.

# %%
# Variables used to set up GitHub.
token = userdata.get('token')
email = userdata.get('email')
username = userdata.get('username')
orgname = 'DecisionTreeBruining'
repo = '212B-ML-Project'

# %%
# Configure git for commiting to GitHub.
# !git config --global user.email "{email}"
# !git config --global user.name "{username}"

# Clone git to Google Colab System.
# !pwd
# !git clone https://{token}@github.com/{orgname}/{repo}.git

# Show repo
# !ls -a {repo}
# Out:
# /content
# fatal: destination path '212B-ML-Project' already exists and is not an empty directory.
# .  ..  assignemnt_1  .git  README.md

# %% [markdown]
# ### Connecting to Google Drive
#
# All of the data will be stored on Google Drive. To use that data, we mount the drive using the `drive.mount()` function below.
#
# Make sure you create a shortcut in your MyDrive for the DecisionTreeBruins folder.
#
# The Data will be located in `/content/drive/MyDrive/DecisionTreeBruining`.

# %%
# Data will be stored on Google Drive.
# Mount DecisionTreeBruins folders from Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Change Directory to the Data Folder. Below is the directory
# %cd /content/drive/MyDrive/DecisionTreeBruining
# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/DecisionTreeBruining
# /content/drive/MyDrive/DecisionTreeBruining

# %% [markdown]
# ---
#
# ## Data Analysis of **TBD**

# %%
# %%R
# h <- 123
# h
# Out:
# [1] 123

# %%
# Committing to git from Google Colab:
# The cloned git is only on the Google Colab Instance. To commit,
# you need to copy from Google Drive to the Cloned folder on the
# Google Colab Instance.
# Uncomment the code below.
# %cp /content/drive/MyDrive/DecisionTreeBruining/Colab_Notebooks/Assignment1.ipynb /content/212B-ML-Project/assignemnt_1/
# %cd /content/212B-ML-Project/
# !git add assignemnt_1/
# !git commit -m "From Google Colab - $(date)"
# !git push
# Out:
# /content/212B-ML-Project
# [main 09a4483] From Google Colab - Sun Mar 31 10:50:04 PM UTC 2024
#  1 file changed, 1 insertion(+)
#  create mode 100644 assignemnt_1/Assignment1.ipynb
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (4/4), 2.53 KiB | 2.53 MiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/DecisionTreeBruining/212B-ML-Project.git
#    99846e2..09a4483  main -> main

# %%
# %cd /content/
# !ls -a
# Out:
# /content
# .  ..  212B-ML-Project	.config  drive	sample_data
