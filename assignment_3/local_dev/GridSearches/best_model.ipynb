# %%
import pandas as pd
import gt

# Data for the table
data = {
    "Hyperparameter": ["Baseline", "Number of Layers and Neurons", "Activation Function", "Initial Learning Rate", "Maximum Iterations", "Number of Iterations with No Change", "Batch Size", "Regularization Parameter (Alpha)"],
    "Value": ["Adam, 1 layer, 100 neurons, ReLU, 0.001, 200, 10, auto, 0.0001",
              "[100, 100, 100, 100, 100]", 
              "logistic", 
              "0.01", 
              "100", 
              "100", 
              "100", 
              "0.0"],
    "Recall": [0.75, 0.52, 0.66, 0.77, 0.75, 0.71, 0.74, 0.72],
    "ROC AUC": [0.81, 0.76, 0.79, 0.82, 0.81, 0.81, 0.82, 0.81],
    "Accuracy": [0.73, 0.81, 0.75, 0.73, 0.73, 0.75, 0.74, 0.75],
    "Fit Time (s)": [67, 833, 154, 73, 106, 399, 151, 102]
}

# Create a DataFrame
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 25
#      22 df = pd.DataFrame(data)
#      24 # Create the gt table
# ---> 25 table = gt.show(df)
#      27 # Render the table
#      28 table.render("html")
#
# AttributeError: module 'gt' has no attribute 'show'

# %%
import pandas as pd
from great_tables import GT, md, html, from_column, style, loc

# Data for the table
data = {
    "Hyperparameter": ["Baseline", "Number of Layers and Neurons", "Activation Function", "Initial Learning Rate", "Maximum Iterations", "Number of Iterations with No Change", "Batch Size", "Regularization Parameter (Alpha)"],
    "Value": ["Adam, 1 layer, 100 neurons, ReLU, 0.001, 200, 10, auto, 0.0001",
              "[100, 100, 100, 100, 100]", 
              "logistic", 
              "0.01", 
              "100", 
              "100", 
              "100", 
              "0.0"],
    "Recall": [0.75, 0.52, 0.66, 0.77, 0.75, 0.71, 0.74, 0.72],
    "ROC AUC": [0.81, 0.76, 0.79, 0.82, 0.81, 0.81, 0.82, 0.81],
    "Accuracy": [0.73, 0.81, 0.75, 0.73, 0.73, 0.75, 0.74, 0.75],
    "Fit Time (s)": [67, 833, 154, 73, 106, 399, 151, 102]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Create the GT table
table = GT(df)

# Apply some styling
table = table.set_style(
    style={
        loc.header(): {
            "background-color": "#f7f7f7",
            "font-weight": "bold",
        },
        loc.body(): {
            "border": "1px solid #dddddd",
            "padding": "8px",
        },
        loc.column("Hyperparameter"): {
            "text-align": "left",
            "font-weight": "bold",
        },
        loc.columns(["Value", "Recall", "ROC AUC", "Accuracy", "Fit Time (s)"]): {
            "text-align": "center",
        }
    }
)

# Display the table in Markdown format (for Jupyter Notebook or similar)
print(md(table))

# Display the table in HTML format (for web embedding)
print(html(table))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 28
#      25 table = GT(df)
#      27 # Apply some styling
# ---> 28 table = table.set_style(
#      29     style={
#      30         loc.header(): {
#      31             "background-color": "#f7f7f7",
#      32             "font-weight": "bold",
#      33         },
#      34         loc.body(): {
#      35             "border": "1px solid #dddddd",
#      36             "padding": "8px",
#      37         },
#      38         loc.column("Hyperparameter"): {
#      39             "text-align": "left",
#      40             "font-weight": "bold",
#      41         },
#      42         loc.columns(["Value", "Recall", "ROC AUC", "Accuracy", "Fit Time (s)"]): {
#      43             "text-align": "center",
#      44         }
#      45     }
#      46 )
#      48 # Display the table in Markdown format (for Jupyter Notebook or similar)
#      49 print(md(table))
#
# AttributeError: 'GT' object has no attribute 'set_style'

# %%
# Data for the table
data = {
    "Hyperparameter": ["Baseline Hyperparameters", 
                       "Number of Layers and Neurons", 
                       "Activation Function", 
                       "Initial Learning Rate", 
                       "Maximum Iterations", 
                       "Number of Iterations with No Change", 
                       "Batch Size", 
                       "Regularization Parameter (Alpha)"],
    "Initial Value": ["-", 
                      [100], 
                      "ReLU", 
                      "0.001", 
                      "200", 
                      "10", 
                      "Auto", 
                      "0.0001"],
    "Optimized Value": ["-",
              "[47, 46, 46, 46]", 
              "logistic", 
              "0.01", 
              "100", 
              "100", 
              "100", 
              "0.0"],
    "Recall": [0.75, 0.00, 0.66, 0.77, 0.75, 0.71, 0.74, 0.72],
    "ROC AUC": [0.81, 0.00, 0.79, 0.82, 0.81, 0.81, 0.82, 0.81],
    "Accuracy": [0.73, 0.00, 0.75, 0.73, 0.73, 0.75, 0.74, 0.75],
    "Fit Time (s)": [67, 0.00, 154, 73, 106, 399, 151, 102]
}

# Adam, 1 layer, 100 neurons, ReLU, 0.001, 200, 10, auto, 0.0001

# Create a DataFrame
df = pd.DataFrame(data)

df

# change slightly so that there is a column with Adam, 1 layer, 100 neurons, ReLU, 0.001, 200, 10, auto, 0.0001 to compare with the other values
# Out:
#                         Hyperparameter Initial Value   Optimized Value  \
# 0             Baseline Hyperparameters             -                 -
# 1         Number of Layers and Neurons         [100]  [47, 46, 46, 46]
# 2                  Activation Function          ReLU          logistic
# 3                Initial Learning Rate         0.001              0.01
# 4                   Maximum Iterations           200               100
# 5  Number of Iterations with No Change            10               100
# 6                           Batch Size          Auto               100
# 7     Regularization Parameter (Alpha)        0.0001               0.0
#
#    Recall  ROC AUC  Accuracy  Fit Time (s)
# 0    0.75     0.81      0.73          67.0
# 1    0.00     0.00      0.00           0.0
# 2    0.66     0.79      0.75         154.0
# 3    0.77     0.82      0.73          73.0
# 4    0.75     0.81      0.73         106.0
# 5    0.71     0.81      0.75         399.0
# 6    0.74     0.82      0.74         151.0
# 7    0.72     0.81      0.75         102.0

# %%
# Remove the first row
df_2 = df.iloc[1:]

df_2
# Out:
#                         Hyperparameter             Value  Recall  ROC AUC  \
# 1         Number of Layers and Neurons  [47, 46, 46, 46]    0.00     0.00
# 2                  Activation Function          logistic    0.66     0.79
# 3                Initial Learning Rate              0.01    0.77     0.82
# 4                   Maximum Iterations               100    0.75     0.81
# 5  Number of Iterations with No Change               100    0.71     0.81
# 6                           Batch Size               100    0.74     0.82
# 7     Regularization Parameter (Alpha)               0.0    0.72     0.81
#
#    Accuracy  Fit Time (s)
# 1      0.00           0.0
# 2      0.75         154.0
# 3      0.73          73.0
# 4      0.73         106.0
# 5      0.75         399.0
# 6      0.74         151.0
# 7      0.75         102.0
