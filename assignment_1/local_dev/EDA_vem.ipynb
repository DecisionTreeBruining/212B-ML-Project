# %%
#Library imports
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pwd
data_dir = '../../Data/heart_2022_with_nans.csv'
heart_d = pd.read_csv(data_dir)
# Out:
# /Users/vemnazarian/212B-ML-Project/assignment_1/local_dev

# %%
# Display the first 5 rows of the dataset
heart_d.head()

# Display all the columns in the dataset
heart_d.columns

# Display the dataset with only variables HadHeartAttack, HadAngina, and HadStroke
heart_d[['HadHeartAttack', 'HadAngina', 'HadStroke']]
# Out:
#        HadHeartAttack HadAngina HadStroke
# 0                  No        No        No
# 1                  No        No        No
# 2                  No        No        No
# 3                  No        No        No
# 4                  No        No        No
# ...               ...       ...       ...
# 445127             No        No        No
# 445128             No        No        No
# 445129             No        No        No
# 445130            Yes        No        No
# 445131             No        No        No
#
# [445132 rows x 3 columns]

# %%
# Frequency Table for HadHeartAttack, HadAngina, and HadStroke
heart_d['HadHeartAttack'].value_counts()
heart_d['HadAngina'].value_counts()
heart_d['HadStroke'].value_counts()

# Combined
heart_d[['HadHeartAttack', 'HadAngina', 'HadStroke']].apply(pd.Series.value_counts)

# Sepeate countplots for HadHeartAttack, HadAngina, and HadStroke
sns.countplot(x = 'HadHeartAttack', data = heart_d)
plt.show()

sns.countplot(x = 'HadAngina', data = heart_d)
plt.show()

sns.countplot(x = 'HadStroke', data = heart_d)
plt.show()

# %%
# Make a new dataframe with only the variables HadHeartAttack, HadAngina, and HadStroke
heart_d_2 = heart_d[['HadHeartAttack', 'HadAngina', 'HadStroke']]

# Frequency Table for HadHeartAttack, HadAngina, and HadStroke
# heart_d_2.apply(pd.Series.value_counts)

# Convert Yes and No to 1 and 0
heart_d_2 = heart_d_2.replace('Yes', 1)
heart_d_2 = heart_d_2.replace('No', 0)

# Convert to string
heart_d_2 = heart_d_2.astype(str)

# Frequency Table for HadHeartAttack, HadAngina, and HadStroke
heart_d_2.apply(pd.Series.value_counts)
# Out:
# /var/folders/_n/xmv95vl9347b3zn8xl2bwlt40000gn/T/ipykernel_49940/1889411457.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heart_d_2 = heart_d_2.replace('No', 0)
#      HadHeartAttack  HadAngina  HadStroke
# 0.0          416959     414176     424336
# 1.0           25108      26551      19239
# nan            3065       4405       1557
